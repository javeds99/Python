# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\javed\instacart Basket Analysis'

# %%
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_added_cols.pkl'))

# %%
df = ords_prods_merged[:1000000]

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number' : ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merged.head(20)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# 13   2715276       15    prior            21                   1
# 14    487368       15    prior            22                   1
# 15   2293453       19    prior             2                   5
# 16   1973799       19    prior             5                   6
# 17    532817       19    prior             7                   4
# 18   1573906       21    prior            10                   3
# 19   1593000       31    prior            10                   3
#
#     order_hour_of_day  product_id  add_to_cart_order  reordered _merge  \
# 0                   8         196                  1          0   both
# 1                   7         196                  1          1   both
# 2                  12         196                  1          1   both
# 3                   7         196                  1          1   both
# 4                  15         196                  1          1   both
# 5                   7         196                  1          1   both
# 6                   9         196                  1          1   both
# 7                  14         196                  2          1   both
# 8                  16         196                  4          1   both
# 9                   8         196                  1          1   both
# 10                  9         196                  2          0   both
# 11                 16         196                  6          1   both
# 12                 11         196                  1          1   both
# 13                  9         196                  1          1   both
# 14                 10         196                  1          1   both
# 15                 14         196                  3          0   both
# 16                 12         196                 15          1   both
# 17                 17         196                  1          1   both
# 18                 10         196                  2          0   both
# 19                  8         196                 17          0   both
#
#    product_name  aisle_id  department_id  prices        price_range  \
# 0          Soda        77              7     9.0  Mid Range Product
# 1          Soda        77              7     9.0  Mid Range Product
# 2          Soda        77              7     9.0  Mid Range Product
# 3          Soda        77              7     9.0  Mid Range Product
# 4          Soda        77              7     9.0  Mid Range Product
# 5          Soda        77              7     9.0  Mid Range Product
# 6          Soda        77              7     9.0  Mid Range Product
# 7          Soda        77              7     9.0  Mid Range Product
# 8          Soda        77              7     9.0  Mid Range Product
# 9          Soda        77              7     9.0  Mid Range Product
# 10         Soda        77              7     9.0  Mid Range Product
# 11         Soda        77              7     9.0  Mid Range Product
# 12         Soda        77              7     9.0  Mid Range Product
# 13         Soda        77              7     9.0  Mid Range Product
# 14         Soda        77              7     9.0  Mid Range Product
# 15         Soda        77              7     9.0  Mid Range Product
# 16         Soda        77              7     9.0  Mid Range Product
# 17         Soda        77              7     9.0  Mid Range Product
# 18         Soda        77              7     9.0  Mid Range Product
# 19         Soda        77              7     9.0  Mid Range Product
#
#        busiest_days busiest_period_of_day  max_order
# 0    Regularly Busy        Average Orders         10
# 1   Least Busy Days        Average Orders         10
# 2   Least Busy Days        Average Orders         10
# 3   Least Busy Days        Average Orders         10
# 4   Least Busy Days        Average Orders         10
# 5    Regularly Busy        Average Orders         10
# 6      Busiest Days           Most Orders         10
# 7      Busiest Days        Average Orders         10
# 8      Busiest Days        Average Orders         10
# 9   Least Busy Days        Average Orders         10
# 10     Busiest Days           Most Orders         22
# 11   Regularly Busy        Average Orders         22
# 12   Regularly Busy           Most Orders         22
# 13     Busiest Days           Most Orders         22
# 14     Busiest Days           Most Orders         22
# 15   Regularly Busy        Average Orders          7
# 16   Regularly Busy        Average Orders          7
# 17  Least Busy Days        Average Orders          7
# 18  Least Busy Days           Most Orders         33
# 19  Least Busy Days        Average Orders         17
