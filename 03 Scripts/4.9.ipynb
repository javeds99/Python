# %%
import pandas as pd
import numpy as np
import os
import scipy 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = r'C:\Users\javed\instacart Basket Analysis'

# %%
df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ex8.pkl'))

# %%
df['orders_day_of_week'].value_counts().plot.bar(color = ['red'])
# Out:
# <AxesSubplot:>

# %%
bar = df['orders_day_of_week'].value_counts().plot.bar(color =['purple', 'red', 'pink', 'orange', 'yellow', 'green', 'blue'])

# %%
bar.figure.savefig(os.path.join(path, '04 Analysis','Visualizations', 'bar_orders_dow.png'))

# %%
df['Age'].plot.hist(bins = 18-24),[24-30])
# Out:
#   File "<ipython-input-11-c3cbd749b5fc>", line 1
#     df['Age'].plot.hist(bins = (18-24),(24-30))
#                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.scatterplot(x = 'prices', y = 'prices', data = df)
# Out:
# <AxesSubplot:xlabel='prices', ylabel='prices'>

# %%
df.loc[df['prices'] > 100, 'prices'] = np.nan

# %%
hist = df['prices'].plot.hist(bins= [25,50,75,100])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fc57a3512603> in <module>
# ----> 1 hist = df['prices'].plot.hist(bins= [25,50,75,100])
#
# NameError: name 'df' is not defined

# %%
np.random.seed(4)
dev = np.random.rand(len(df)) <= 0.7

# %%
big = df[dev]

# %%
small = df[~dev]

# %%
df2 = small[['orders_day_of_week', 'prices']]

# %%
line = sns.lineplot(data = df2, x = 'orders_day_of_week', y= 'prices')
